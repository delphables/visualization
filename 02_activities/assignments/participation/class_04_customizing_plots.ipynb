# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label="Person 1")
ax.plot(x, y2, label="Person 2")
ax.legend(loc="lower right")
plt.show()

# %%
ax.legend(
    loc="lower right",
    fontsize=12,
    ncol=2,
    frameon=True,
    shadow=True
)

# %%
ax.annotate(
    "Important point",
    xy=(10, y1[10]),
    xytext=(20, 80),
    arrowprops=dict(arrowstyle="->", color="black")
)
# Out:
# Text(20, 80, 'Important point')

# %%
font1 = {"family": "serif", "color": "indigo"}
plt.xlabel("Shiny New X Axis!", fontsize=18, fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
plt.xticks(rotation=45, ha="right")
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %% [markdown]
# # Notes – Class 4
#
# - Learned how to customize legends (position, font size, columns)
# - Used annotations and arrows to highlight important points
# - Learned how to rotate axis labels for readability
# - Applied matplotlib styles to quickly change aesthetics
